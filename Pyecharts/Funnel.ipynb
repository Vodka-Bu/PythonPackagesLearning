# %% [markdown]
# # 漏斗图

# %% [markdown]
# ## 特殊配置项

# %% [markdown]
# **name -> str**
# 图例名称
#
# **attr -> list**
# 属性名称
#
# **value -> list**
# 属性所对应的值
#
# **funnel_sort -> str/func**
# 数据排序， 可以取 'ascending'，'descending'，'none'（表示按 data 顺序，即不排序）。
#
# **funnel_gap- > int**
# 数据图形间距。默认为 0。

# %% [markdown]
# ## 基本示例

# %% [markdown]
# ### label 显示在内部

# %%
## label 显示在内部
from pyecharts import Funnel

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
funnel = Funnel("漏斗图示例")
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="33c263ad38ab4b95a3c55e100a786a86" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_33c263ad38ab4b95a3c55e100a786a86 = echarts.init(document.getElementById('33c263ad38ab4b95a3c55e100a786a86'), 'light', {renderer: 'canvas'});
#
# var option_33c263ad38ab4b95a3c55e100a786a86 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6567372,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u889c\u5b50",
#                 "\u88e4\u5b50",
#                 "\u96ea\u7eba\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u9ad8\u8ddf\u978b"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_33c263ad38ab4b95a3c55e100a786a86.setOption(option_33c263ad38ab4b95a3c55e100a786a86);
#
#     });
# </script>

# %% [markdown]
# ### label 显示在外部

# %%
# 显示在外部

funnel = Funnel("漏斗图示例")
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="outside"
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="93c0f8920d924c1ead1e8568a0b7cea0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_93c0f8920d924c1ead1e8568a0b7cea0 = echarts.init(document.getElementById('93c0f8920d924c1ead1e8568a0b7cea0'), 'light', {renderer: 'canvas'});
#
# var option_93c0f8920d924c1ead1e8568a0b7cea0 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5923479,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u889c\u5b50",
#                 "\u88e4\u5b50",
#                 "\u96ea\u7eba\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u9ad8\u8ddf\u978b"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_93c0f8920d924c1ead1e8568a0b7cea0.setOption(option_93c0f8920d924c1ead1e8568a0b7cea0);
#
#     });
# </script>

# %% [markdown]
# ## 图例按照顺序输出
#
# 在上面的画图过程中发现图例的顺序比较随机，强迫症可能希望图例的顺序也是按照既定顺序，利用print_echarts_options发现legend里的data字段顺序其实就是真正图例显示的顺序。
#
# 注意一下操作涉及到修改 _option 私有变量，理论上是不被允许的，但是暂时没找到更好的做法

# %%
funnel = Funnel("漏斗图示例")
# 基础设置
funnel.use_theme('macarons')
funnel.add(
    "商品",
    attr,
    value,
    is_label_show=True,
    label_pos="inside",
    funnel_sort='ascending'
)
# 获得legend_option
legend_option = funnel.options['legend']
# 修改相应值
legend_option[0]['data'] = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
# 将相应值传回 _option， 官方貌似没有提供安全修改 _option 的方式
funnel._option['legend'] = legend_option
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'macarons': '/nbextensions/echarts-themes-js/macarons'
#         }
#     });
# </script>
#     <div id="786a4cc887fc4caf93749d3109b06bc6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'macarons'], function(echarts) {
#
# var myChart_786a4cc887fc4caf93749d3109b06bc6 = echarts.init(document.getElementById('786a4cc887fc4caf93749d3109b06bc6'), 'macarons', {renderer: 'canvas'});
#
# var option_786a4cc887fc4caf93749d3109b06bc6 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3565407,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 120
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": []
# };
# myChart_786a4cc887fc4caf93749d3109b06bc6.setOption(option_786a4cc887fc4caf93749d3109b06bc6);
#
#     });
# </script>

# %% [markdown]
# ## 百分比展示
#
# * 对 tooltip 的使用并不是能够十分随心所欲，基本不用想输入原数据，自动算出隔层的转化率这种操作（并且能根据图例筛选而改变），因此最靠谱的方法还是提前算出百分比

# %%
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
data = []
for i,j in enumerate(attr):
    data.append(int(value[i]/max(value)*100))  
data
# Out:
# [16, 33, 50, 66, 83, 100]

# %%
# 因为不知道 marker 原点的代码，所以用function形式来写 tooltip
def tooltip_format(params):
    return params.seriesName + '<br/>' + params.marker +params.name + ': ' + params.value + '%'

# %%
funnel = Funnel("漏斗图示例")
# 基础设置
funnel.use_theme('macarons')
funnel.add(
    "商品",
    attr,
    data,
    is_label_show=True,
    label_pos="inside",
    funnel_sort='ascending',
    tooltip_formatter = tooltip_format
)
# 获得legend_option
legend_option = funnel.options['legend']
# 修改相应值
legend_option[0]['data'] = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
# 将相应值传回 _option， 官方貌似没有提供安全修改 _option 的方式
funnel._option['legend'] = legend_option
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'macarons': '/nbextensions/echarts-themes-js/macarons'
#         }
#     });
# </script>
#     <div id="61cb90cf5b1e413cb52ee72826a61055" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'macarons'], function(echarts) {
#
# var myChart_61cb90cf5b1e413cb52ee72826a61055 = echarts.init(document.getElementById('61cb90cf5b1e413cb52ee72826a61055'), 'macarons', {renderer: 'canvas'});
# function tooltip_format(params) {
#     return ((((((params.seriesName + "<br/>") + params.marker) + params.name) + ": ") + params.value) + "%");
# }
#
# var option_61cb90cf5b1e413cb52ee72826a61055 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3337970,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": tooltip_format,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 100
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": []
# };
# myChart_61cb90cf5b1e413cb52ee72826a61055.setOption(option_61cb90cf5b1e413cb52ee72826a61055);
#
#     });
# </script>
